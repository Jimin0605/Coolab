# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab Notebooks/OpenSourceProgramming/Coolab
# Out:
# /content/drive/MyDrive/Colab Notebooks/OpenSourceProgramming/Coolab

# %%
# !git config --global user.email "wweww1596@gmail.com"
# !git config --global user.name "Jimin0605"

# %%
# !git add .

# %%
# !git commit -m "first commit"
# Out:
# [main 4bb6cf6] first commit
#  4 files changed, 2 insertions(+), 2 deletions(-)
#  delete mode 100644 Untitled
#  delete mode 100644 Untitled0.ipynb
#  create mode 100644 Untitled1.ipynb
#  create mode 100644 "git\341\204\206\341\205\247\341\206\274\341\204\205\341\205\247\341\206\274\341\204\213\341\205\245.ipynb"

# %%
# !git push
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.72 KiB | 352.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/Jimin0605/Coolab.git
#    a5691df..4bb6cf6  main -> main
